# %%
#Lấy dữ liệu ở trong file csv
f = open('data.csv', 'r',encoding='utf8')
line = f.readline()
toan = []
van = []
anh =  []
ly = []
hoa = []
sinh = []
su = []
dia = []
gdcd = []
for line in f.readlines():
    line = line.split(',')
    if line[3] != '0' :
        toan.append(float(line[3]))
    if line[4] != '0' :
        van.append(float(line[4]))
    if line[5] != '0' :
        anh.append(float(line[5]))
    if line[6] != '0' :
        ly.append(float(line[6]))
    if line[7] != '0' :
        hoa.append(float(line[7]))
    if line[8] != '0' :
        sinh.append(float(line[8]))
    if line[9] != '0' :
        su.append(float(line[9]))
    if line[10] != '0' :
        dia.append(float(line[10]))
    if line[11] != '0' :
        gdcd.append(float(line[11]))
f.close()
# Close file

# %%
import numpy as np
toan = np.array(toan)
van = np.array(van)
anh = np.array(anh)
ly = np.array(ly)
hoa = np.array(hoa)
sinh = np.array(sinh)
su = np.array(su)
dia = np.array(dia)
gdcd = np.array(gdcd)

# %%
# Môn toán 
from matplotlib import pyplot as plt
# %matplotlib inline 

# Trung bình và trung vị 
toan.mean(), np.median(toan)

# Xem có bao nhiêu đầu điểm
unique = np.unique(toan)
print(unique)

# Đếm xem mỗi đầu điểm có bao nhiêu người
a = list(toan)
freq = [a.count(b) for b in unique]
print(freq)

# Đồ thị
plt.bar(unique, freq, width=0.3)
plt.xticks(unique, rotation=90)
# Out:
# [ 8.6  8.8  9.   9.2  9.4  9.6  9.8 10. ]
# [36, 85, 192, 816, 1448, 2022, 1380, 258]
# ([<matplotlib.axis.XTick at 0x22f779fe3d0>,
#   <matplotlib.axis.XTick at 0x22f779fe610>,
#   <matplotlib.axis.XTick at 0x22f779f0b20>,
#   <matplotlib.axis.XTick at 0x22f779b2340>,
#   <matplotlib.axis.XTick at 0x22f779d0910>,
#   <matplotlib.axis.XTick at 0x22f779eb280>,
#   <matplotlib.axis.XTick at 0x22f779e7af0>,
#   <matplotlib.axis.XTick at 0x22f779ca730>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Môn văn
from matplotlib import pyplot as plt
# %matplotlib inline
 
# Trung bình và trung vị 
van.mean(), np.median(van)

# Xem có bao nhiêu đầu điểm
unique = np.unique(van)
print(unique)

# Đếm xem mỗi đầu điểm có bao nhiêu người
a = list(van)
freq = [a.count(b) for b in unique]
print(freq)

# Đồ thị
plt.bar(unique, freq, width=0.3)
plt.xticks(unique, rotation=90)
# Out:
# [3.   3.25 3.5  3.75 4.   4.25 4.5  4.75 5.   5.23 5.25 5.5  5.67 5.75
#  5.92 6.   6.08 6.1  6.17 6.25 6.33 6.42 6.5  6.66 6.67 6.75 6.83 6.92
#  7.   7.17 7.25 7.33 7.41 7.42 7.5  7.74 7.75 7.83 8.   8.08 8.17 8.25
#  8.5  8.75 9.   9.25 9.5  9.75]
# [1, 3, 4, 10, 28, 39, 52, 44, 77, 1, 88, 155, 1, 234, 1, 373, 1, 1, 1, 381, 2, 1, 465, 1, 1, 485, 3, 1, 659, 2, 492, 3, 1, 4, 529, 1, 419, 1, 458, 1, 1, 296, 316, 173, 119, 32, 13, 3]
# ([<matplotlib.axis.XTick at 0x22f7789e8b0>,
#   <matplotlib.axis.XTick at 0x22f7789ea90>,
#   <matplotlib.axis.XTick at 0x22f77906ca0>,
#   <matplotlib.axis.XTick at 0x22f77aa9eb0>,
#   <matplotlib.axis.XTick at 0x22f77ab8640>,
#   <matplotlib.axis.XTick at 0x22f77ab8d90>,
#   <matplotlib.axis.XTick at 0x22f77abe520>,
#   <matplotlib.axis.XTick at 0x22f77abec70>,
#   <matplotlib.axis.XTick at 0x22f77abe850>,
#   <matplotlib.axis.XTick at 0x22f77ab8610>,
#   <matplotlib.axis.XTick at 0x22f77ac5490>,
#   <matplotlib.axis.XTick at 0x22f77ac5be0>,
#   <matplotlib.axis.XTick at 0x22f77acd370>,
#   <matplotlib.axis.XTick at 0x22f77acdac0>,
#   <matplotlib.axis.XTick at 0x22f77ad3250>,
#   <matplotlib.axis.XTick at 0x22f77acd580>,
#   <matplotlib.axis.XTick at 0x22f77aa9df0>,
#   <matplotlib.axis.XTick at 0x22f77ad3640>,
#   <matplotlib.axis.XTick at 0x22f77ad3d90>,
#   <matplotlib.axis.XTick at 0x22f77adb520>,
#   <matplotlib.axis.XTick at 0x22f77adbc70>,
#   <matplotlib.axis.XTick at 0x22f77adbe80>,
#   <matplotlib.axis.XTick at 0x22f77ad3d60>,
#   <matplotlib.axis.XTick at 0x22f77acd790>,
#   <matplotlib.axis.XTick at 0x22f77ae2910>,
#   <matplotlib.axis.XTick at 0x22f77ae7160>,
#   <matplotlib.axis.XTick at 0x22f77ae77f0>,
#   <matplotlib.axis.XTick at 0x22f77ae7f40>,
#   <matplotlib.axis.XTick at 0x22f77ae7730>,
#   <matplotlib.axis.XTick at 0x22f77ae2490>,
#   <matplotlib.axis.XTick at 0x22f77af0490>,
#   <matplotlib.axis.XTick at 0x22f77af0be0>,
#   <matplotlib.axis.XTick at 0x22f77af8370>,
#   <matplotlib.axis.XTick at 0x22f77af8ac0>,
#   <matplotlib.axis.XTick at 0x22f77af8cd0>,
#   <matplotlib.axis.XTick at 0x22f77af0ee0>,
#   <matplotlib.axis.XTick at 0x22f77ae2d00>,
#   <matplotlib.axis.XTick at 0x22f77abee80>,
#   <matplotlib.axis.XTick at 0x22f77afe880>,
#   <matplotlib.axis.XTick at 0x22f77b060d0>,
#   <matplotlib.axis.XTick at 0x22f77b06760>,
#   <matplotlib.axis.XTick at 0x22f77afe8e0>,
#   <matplotlib.axis.XTick at 0x22f77af08e0>,
#   <matplotlib.axis.XTick at 0x22f77b06c70>,
#   <matplotlib.axis.XTick at 0x22f77b0e400>,
#   <matplotlib.axis.XTick at 0x22f77b0eb50>,
#   <matplotlib.axis.XTick at 0x22f77b562e0>,
#   <matplotlib.axis.XTick at 0x22f77b0ee80>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Môn anh
from matplotlib import pyplot as plt
# %matplotlib inline
 
# Trung bình và trung vị 
anh.mean(), np.median(anh)

# Xem có bao nhiêu đầu điểm
unique = np.unique(anh)
print(unique)

# Đếm xem mỗi đầu điểm có bao nhiêu người
a = list(anh)
freq = [a.count(b) for b in unique]
print(freq)

# Đồ thị
plt.bar(unique, freq, width=0.3)
plt.xticks(unique, rotation=90)
# Out:
# [ 1.2  1.6  1.8  2.   2.2  2.4  2.6  2.8  3.   3.2  3.4  3.6  3.8  4.
#   4.2  4.4  4.6  4.8  5.   5.2  5.4  5.6  5.8  6.   6.2  6.4  6.6  6.8
#   7.   7.2  7.4  7.6  7.8  8.   8.2  8.4  8.6  8.8  9.   9.2  9.4  9.6
#   9.8 10. ]
# [1, 1, 2, 4, 6, 23, 17, 22, 38, 41, 61, 72, 103, 125, 122, 151, 178, 182, 208, 229, 250, 219, 223, 249, 223, 211, 202, 203, 194, 180, 165, 200, 177, 209, 221, 205, 208, 231, 181, 151, 114, 86, 44, 8]
# ([<matplotlib.axis.XTick at 0x22f77a544f0>,
#   <matplotlib.axis.XTick at 0x22f77a544c0>,
#   <matplotlib.axis.XTick at 0x22f77a51100>,
#   <matplotlib.axis.XTick at 0x22f77c109d0>,
#   <matplotlib.axis.XTick at 0x22f77c28160>,
#   <matplotlib.axis.XTick at 0x22f77c281c0>,
#   <matplotlib.axis.XTick at 0x22f77c28a60>,
#   <matplotlib.axis.XTick at 0x22f77c301f0>,
#   <matplotlib.axis.XTick at 0x22f77c30970>,
#   <matplotlib.axis.XTick at 0x22f77c37100>,
#   <matplotlib.axis.XTick at 0x22f77c37850>,
#   <matplotlib.axis.XTick at 0x22f77c305e0>,
#   <matplotlib.axis.XTick at 0x22f77c28610>,
#   <matplotlib.axis.XTick at 0x22f77c37e80>,
#   <matplotlib.axis.XTick at 0x22f77c3f610>,
#   <matplotlib.axis.XTick at 0x22f77c3fd60>,
#   <matplotlib.axis.XTick at 0x22f77c444f0>,
#   <matplotlib.axis.XTick at 0x22f77c44c40>,
#   <matplotlib.axis.XTick at 0x22f77c44550>,
#   <matplotlib.axis.XTick at 0x22f77c3f1f0>,
#   <matplotlib.axis.XTick at 0x22f77c4a130>,
#   <matplotlib.axis.XTick at 0x22f77c4a7c0>,
#   <matplotlib.axis.XTick at 0x22f77c4af10>,
#   <matplotlib.axis.XTick at 0x22f77c526a0>,
#   <matplotlib.axis.XTick at 0x22f77c52df0>,
#   <matplotlib.axis.XTick at 0x22f77c52220>,
#   <matplotlib.axis.XTick at 0x22f77c28910>,
#   <matplotlib.axis.XTick at 0x22f77c58220>,
#   <matplotlib.axis.XTick at 0x22f77c58970>,
#   <matplotlib.axis.XTick at 0x22f77c5e100>,
#   <matplotlib.axis.XTick at 0x22f77c5e850>,
#   <matplotlib.axis.XTick at 0x22f77c5efa0>,
#   <matplotlib.axis.XTick at 0x22f77c588b0>,
#   <matplotlib.axis.XTick at 0x22f77c4aa90>,
#   <matplotlib.axis.XTick at 0x22f77c60460>,
#   <matplotlib.axis.XTick at 0x22f77c60bb0>,
#   <matplotlib.axis.XTick at 0x22f77c6d340>,
#   <matplotlib.axis.XTick at 0x22f77c6da90>,
#   <matplotlib.axis.XTick at 0x22f77c6d640>,
#   <matplotlib.axis.XTick at 0x22f77c60490>,
#   <matplotlib.axis.XTick at 0x22f77c58550>,
#   <matplotlib.axis.XTick at 0x22f77c78130>,
#   <matplotlib.axis.XTick at 0x22f77c787c0>,
#   <matplotlib.axis.XTick at 0x22f77c78f10>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Môn ly
from matplotlib import pyplot as plt
# %matplotlib inline
 
# Trung bình và trung vị 
ly.mean(), np.median(ly)

# Xem có bao nhiêu đầu điểm
unique = np.unique(ly)
print(unique)

# Đếm xem mỗi đầu điểm có bao nhiêu người
a = list(ly)
freq = [a.count(b) for b in unique]
print(freq)

# Đồ thị
plt.bar(unique, freq, width=0.3)
plt.xticks(unique, rotation=90)
# Out:
# [ 1.25  1.5   1.75  2.    2.25  2.5   2.75  3.    3.25  3.5   3.75  4.
#   4.25  4.5   4.75  5.    5.25  5.5   5.75  6.    6.25  6.5   6.75  7.
#   7.25  7.5   7.75  8.    8.25  8.5   8.75  9.    9.25  9.5   9.75 10.  ]
# [2, 1, 2, 1, 1, 4, 6, 13, 15, 22, 26, 27, 46, 48, 63, 74, 69, 80, 92, 81, 112, 103, 138, 137, 186, 229, 316, 450, 509, 587, 577, 561, 443, 330, 248, 123]
# ([<matplotlib.axis.XTick at 0x22f779e7100>,
#   <matplotlib.axis.XTick at 0x22f779e76a0>,
#   <matplotlib.axis.XTick at 0x22f77b7ca60>,
#   <matplotlib.axis.XTick at 0x22f77963f10>,
#   <matplotlib.axis.XTick at 0x22f77968f70>,
#   <matplotlib.axis.XTick at 0x22f77968d00>,
#   <matplotlib.axis.XTick at 0x22f779ad850>,
#   <matplotlib.axis.XTick at 0x22f77969a30>,
#   <matplotlib.axis.XTick at 0x22f779ad4f0>,
#   <matplotlib.axis.XTick at 0x22f77963af0>,
#   <matplotlib.axis.XTick at 0x22f779697f0>,
#   <matplotlib.axis.XTick at 0x22f77974280>,
#   <matplotlib.axis.XTick at 0x22f77974e20>,
#   <matplotlib.axis.XTick at 0x22f77978640>,
#   <matplotlib.axis.XTick at 0x22f7797bc70>,
#   <matplotlib.axis.XTick at 0x22f77978370>,
#   <matplotlib.axis.XTick at 0x22f77969c40>,
#   <matplotlib.axis.XTick at 0x22f7797b6a0>,
#   <matplotlib.axis.XTick at 0x22f7797e5e0>,
#   <matplotlib.axis.XTick at 0x22f7797ec70>,
#   <matplotlib.axis.XTick at 0x22f77980bb0>,
#   <matplotlib.axis.XTick at 0x22f779836a0>,
#   <matplotlib.axis.XTick at 0x22f77980a00>,
#   <matplotlib.axis.XTick at 0x22f7797b280>,
#   <matplotlib.axis.XTick at 0x22f77983c10>,
#   <matplotlib.axis.XTick at 0x22f779837c0>,
#   <matplotlib.axis.XTick at 0x22f77986340>,
#   <matplotlib.axis.XTick at 0x22f77988f40>,
#   <matplotlib.axis.XTick at 0x22f77988cd0>,
#   <matplotlib.axis.XTick at 0x22f77983ca0>,
#   <matplotlib.axis.XTick at 0x22f7797e4c0>,
#   <matplotlib.axis.XTick at 0x22f77990d90>,
#   <matplotlib.axis.XTick at 0x22f77990790>,
#   <matplotlib.axis.XTick at 0x22f7798b340>,
#   <matplotlib.axis.XTick at 0x22f7798b640>,
#   <matplotlib.axis.XTick at 0x22f7798bbe0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Môn hóa
from matplotlib import pyplot as plt
# %matplotlib inline
 
# Trung bình và trung vị 
hoa.mean(), np.median(hoa)

# Xem có bao nhiêu đầu điểm
unique = np.unique(hoa)
print(unique)

# Đếm xem mỗi đầu điểm có bao nhiêu người
a = list(hoa)
freq = [a.count(b) for b in unique]
print(freq)

# Đồ thị
plt.bar(unique, freq, width=0.3)
plt.xticks(unique, rotation=90)
# Out:
# [ 0.75  1.    1.5   1.75  2.    2.25  2.5   2.75  3.    3.25  3.5   3.75
#   4.    4.25  4.5   4.75  5.    5.25  5.5   5.75  6.    6.25  6.5   6.75
#   7.    7.25  7.5   7.75  8.    8.25  8.5   8.75  9.    9.25  9.5   9.75
#  10.  ]
# [1, 2, 4, 3, 4, 6, 13, 15, 24, 38, 50, 68, 107, 127, 166, 224, 247, 298, 311, 353, 354, 342, 300, 337, 293, 254, 223, 197, 172, 161, 147, 175, 180, 158, 150, 82, 52]
# ([<matplotlib.axis.XTick at 0x22f7793edc0>,
#   <matplotlib.axis.XTick at 0x22f7793efd0>,
#   <matplotlib.axis.XTick at 0x22f779390a0>,
#   <matplotlib.axis.XTick at 0x22f77904f70>,
#   <matplotlib.axis.XTick at 0x22f779042e0>,
#   <matplotlib.axis.XTick at 0x22f77901eb0>,
#   <matplotlib.axis.XTick at 0x22f77901070>,
#   <matplotlib.axis.XTick at 0x22f778e42e0>,
#   <matplotlib.axis.XTick at 0x22f778e4580>,
#   <matplotlib.axis.XTick at 0x22f77904100>,
#   <matplotlib.axis.XTick at 0x22f778fee80>,
#   <matplotlib.axis.XTick at 0x22f778fe790>,
#   <matplotlib.axis.XTick at 0x22f778fba00>,
#   <matplotlib.axis.XTick at 0x22f778fb490>,
#   <matplotlib.axis.XTick at 0x22f778f8c70>,
#   <matplotlib.axis.XTick at 0x22f778fbcd0>,
#   <matplotlib.axis.XTick at 0x22f779048e0>,
#   <matplotlib.axis.XTick at 0x22f778f80d0>,
#   <matplotlib.axis.XTick at 0x22f778f5b20>,
#   <matplotlib.axis.XTick at 0x22f778f5820>,
#   <matplotlib.axis.XTick at 0x22f778f0ee0>,
#   <matplotlib.axis.XTick at 0x22f778f0c70>,
#   <matplotlib.axis.XTick at 0x22f778f5430>,
#   <matplotlib.axis.XTick at 0x22f778e4d90>,
#   <matplotlib.axis.XTick at 0x22f778b9190>,
#   <matplotlib.axis.XTick at 0x22f778b98b0>,
#   <matplotlib.axis.XTick at 0x22f778e6160>,
#   <matplotlib.axis.XTick at 0x22f778e6550>,
#   <matplotlib.axis.XTick at 0x22f778e6520>,
#   <matplotlib.axis.XTick at 0x22f778b9640>,
#   <matplotlib.axis.XTick at 0x22f778f0bb0>,
#   <matplotlib.axis.XTick at 0x22f778e32b0>,
#   <matplotlib.axis.XTick at 0x22f778e2250>,
#   <matplotlib.axis.XTick at 0x22f778e2100>,
#   <matplotlib.axis.XTick at 0x22f778dd310>,
#   <matplotlib.axis.XTick at 0x22f778e22b0>,
#   <matplotlib.axis.XTick at 0x22f778f0dc0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Môn sinh
from matplotlib import pyplot as plt
# %matplotlib inline
 
# Trung bình và trung vị 
sinh.mean(), np.median(sinh)

# Xem có bao nhiêu đầu điểm
unique = np.unique(sinh)
print(unique)

# Đếm xem mỗi đầu điểm có bao nhiêu người
a = list(sinh)
freq = [a.count(b) for b in unique]
print(freq)

# Đồ thị
plt.bar(unique, freq, width=0.3)
plt.xticks(unique, rotation=90)
# Out:
# [3.75 4.   4.08 4.17 4.25 4.33 4.42 4.5  4.58 4.67 4.75 4.83 4.92 5.
#  5.08 5.17 5.25 5.33 5.42 5.5  5.58 5.67 5.75 5.83 5.92 6.   6.08 6.17
#  6.25 6.33 6.42 6.5  6.58 6.67 6.75 6.83 6.92 7.   7.08 7.17 7.25 7.33
#  7.42 7.5  7.58 7.67 7.75 7.83 7.92 8.   8.08 8.17 8.25 8.33 8.42 8.5
#  8.58 8.67 8.75 8.83 8.92 9.   9.08 9.17 9.25 9.33 9.42 9.5  9.75 9.83]
# [1, 1, 1, 2, 3, 1, 1, 1, 6, 2, 4, 2, 5, 4, 15, 12, 12, 11, 11, 24, 34, 27, 32, 34, 33, 42, 49, 55, 73, 66, 87, 82, 96, 129, 137, 129, 155, 155, 190, 171, 214, 237, 219, 236, 211, 265, 250, 249, 243, 199, 229, 170, 170, 127, 103, 121, 89, 69, 64, 40, 59, 30, 28, 17, 10, 2, 4, 4, 1, 1]
# ([<matplotlib.axis.XTick at 0x22f778b3eb0>,
#   <matplotlib.axis.XTick at 0x22f778b35b0>,
#   <matplotlib.axis.XTick at 0x22f778b4fd0>,
#   <matplotlib.axis.XTick at 0x22f778bc850>,
#   <matplotlib.axis.XTick at 0x22f778bc4f0>,
#   <matplotlib.axis.XTick at 0x22f778ba190>,
#   <matplotlib.axis.XTick at 0x22f778ba070>,
#   <matplotlib.axis.XTick at 0x22f778aeac0>,
#   <matplotlib.axis.XTick at 0x22f778ae910>,
#   <matplotlib.axis.XTick at 0x22f778a9640>,
#   <matplotlib.axis.XTick at 0x22f778ae4c0>,
#   <matplotlib.axis.XTick at 0x22f778ba6a0>,
#   <matplotlib.axis.XTick at 0x22f778a9fa0>,
#   <matplotlib.axis.XTick at 0x22f76774fa0>,
#   <matplotlib.axis.XTick at 0x22f7688ad00>,
#   <matplotlib.axis.XTick at 0x22f768ab6d0>,
#   <matplotlib.axis.XTick at 0x22f768ab550>,
#   <matplotlib.axis.XTick at 0x22f778a9c10>,
#   <matplotlib.axis.XTick at 0x22f778ae730>,
#   <matplotlib.axis.XTick at 0x22f768ac550>,
#   <matplotlib.axis.XTick at 0x22f768acbb0>,
#   <matplotlib.axis.XTick at 0x22f768b0400>,
#   <matplotlib.axis.XTick at 0x22f768b01f0>,
#   <matplotlib.axis.XTick at 0x22f768b0550>,
#   <matplotlib.axis.XTick at 0x22f768ac7c0>,
#   <matplotlib.axis.XTick at 0x22f768abdc0>,
#   <matplotlib.axis.XTick at 0x22f778b33d0>,
#   <matplotlib.axis.XTick at 0x22f768b2d90>,
#   <matplotlib.axis.XTick at 0x22f768b25e0>,
#   <matplotlib.axis.XTick at 0x22f778a1ac0>,
#   <matplotlib.axis.XTick at 0x22f768b24f0>,
#   <matplotlib.axis.XTick at 0x22f778a90d0>,
#   <matplotlib.axis.XTick at 0x22f778a1d30>,
#   <matplotlib.axis.XTick at 0x22f778a5130>,
#   <matplotlib.axis.XTick at 0x22f778a5280>,
#   <matplotlib.axis.XTick at 0x22f77894a60>,
#   <matplotlib.axis.XTick at 0x22f778949d0>,
#   <matplotlib.axis.XTick at 0x22f77894100>,
#   <matplotlib.axis.XTick at 0x22f778a18b0>,
#   <matplotlib.axis.XTick at 0x22f768a7f40>,
#   <matplotlib.axis.XTick at 0x22f768a75b0>,
#   <matplotlib.axis.XTick at 0x22f778a6070>,
#   <matplotlib.axis.XTick at 0x22f778a6a60>,
#   <matplotlib.axis.XTick at 0x22f778990d0>,
#   <matplotlib.axis.XTick at 0x22f768a7940>,
#   <matplotlib.axis.XTick at 0x22f778a11c0>,
#   <matplotlib.axis.XTick at 0x22f778996a0>,
#   <matplotlib.axis.XTick at 0x22f768bf7c0>,
#   <matplotlib.axis.XTick at 0x22f768bf160>,
#   <matplotlib.axis.XTick at 0x22f768bf730>,
#   <matplotlib.axis.XTick at 0x22f768bf7f0>,
#   <matplotlib.axis.XTick at 0x22f77899d90>,
#   <matplotlib.axis.XTick at 0x22f778a63d0>,
#   <matplotlib.axis.XTick at 0x22f778a31f0>,
#   <matplotlib.axis.XTick at 0x22f768bedc0>,
#   <matplotlib.axis.XTick at 0x22f768be7f0>,
#   <matplotlib.axis.XTick at 0x22f7646cd30>,
#   <matplotlib.axis.XTick at 0x22f768be130>,
#   <matplotlib.axis.XTick at 0x22f778a32b0>,
#   <matplotlib.axis.XTick at 0x22f768bfc40>,
#   <matplotlib.axis.XTick at 0x22f76136d90>,
#   <matplotlib.axis.XTick at 0x22f75ea89d0>,
#   <matplotlib.axis.XTick at 0x22f75ea8610>,
#   <matplotlib.axis.XTick at 0x22f760f7c70>,
#   <matplotlib.axis.XTick at 0x22f75ea8100>,
#   <matplotlib.axis.XTick at 0x22f76136be0>,
#   <matplotlib.axis.XTick at 0x22f76118cd0>,
#   <matplotlib.axis.XTick at 0x22f75e1fc10>,
#   <matplotlib.axis.XTick at 0x22f75ee8220>,
#   <matplotlib.axis.XTick at 0x22f75ee84c0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Môn sử
from matplotlib import pyplot as plt
# %matplotlib inline
 
# Trung bình và trung vị 
su.mean(), np.median(su)

# Xem có bao nhiêu đầu điểm
unique = np.unique(su)
print(unique)

# Đếm xem mỗi đầu điểm có bao nhiêu người
a = list(su)
freq = [a.count(b) for b in unique]
print(freq)

# Đồ thị
plt.bar(unique, freq, width=0.3)
plt.xticks(unique, rotation=90)
# Out:
# [ 5.    5.25  5.5   5.75  6.    6.25  6.5   6.75  7.    7.25  7.5   7.75
#   8.    8.25  8.5   8.75  9.    9.25  9.5   9.75 10.  ]
# [1, 7, 8, 4, 8, 6, 15, 19, 27, 46, 46, 73, 41, 43, 39, 25, 17, 8, 3, 2, 1]
# ([<matplotlib.axis.XTick at 0x22f76511f10>,
#   <matplotlib.axis.XTick at 0x22f76511a30>,
#   <matplotlib.axis.XTick at 0x22f76511d60>,
#   <matplotlib.axis.XTick at 0x22f7661d9a0>,
#   <matplotlib.axis.XTick at 0x22f765f0a00>,
#   <matplotlib.axis.XTick at 0x22f76529a30>,
#   <matplotlib.axis.XTick at 0x22f765ad430>,
#   <matplotlib.axis.XTick at 0x22f765ad340>,
#   <matplotlib.axis.XTick at 0x22f765a8850>,
#   <matplotlib.axis.XTick at 0x22f765a83d0>,
#   <matplotlib.axis.XTick at 0x22f765a28b0>,
#   <matplotlib.axis.XTick at 0x22f765ad910>,
#   <matplotlib.axis.XTick at 0x22f7661d400>,
#   <matplotlib.axis.XTick at 0x22f7659a7c0>,
#   <matplotlib.axis.XTick at 0x22f7659a190>,
#   <matplotlib.axis.XTick at 0x22f76562610>,
#   <matplotlib.axis.XTick at 0x22f765622b0>,
#   <matplotlib.axis.XTick at 0x22f76562310>,
#   <matplotlib.axis.XTick at 0x22f7659a250>,
#   <matplotlib.axis.XTick at 0x22f7652b490>,
#   <matplotlib.axis.XTick at 0x22f7652b9d0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Môn địa
from matplotlib import pyplot as plt
# %matplotlib inline
 
# Trung bình và trung vị 
dia.mean(), np.median(dia)

# Xem có bao nhiêu đầu điểm
unique = np.unique(dia)
print(unique)

# Đếm xem mỗi đầu điểm có bao nhiêu người
a = list(dia)
freq = [a.count(b) for b in unique]
print(freq)

# Đồ thị
plt.bar(unique, freq, width=0.3)
plt.xticks(unique, rotation=90)
# Out:
# [ 5.25  6.    6.25  6.5   6.75  7.    7.25  7.5   7.75  8.    8.25  8.5
#   8.75  9.    9.25  9.5   9.75 10.  ]
# [1, 1, 1, 1, 2, 3, 10, 14, 20, 15, 39, 62, 50, 69, 60, 44, 36, 11]
# ([<matplotlib.axis.XTick at 0x22f7657b4c0>,
#   <matplotlib.axis.XTick at 0x22f7657bb20>,
#   <matplotlib.axis.XTick at 0x22f7657dee0>,
#   <matplotlib.axis.XTick at 0x22f765fef10>,
#   <matplotlib.axis.XTick at 0x22f765fe220>,
#   <matplotlib.axis.XTick at 0x22f765fe580>,
#   <matplotlib.axis.XTick at 0x22f765851f0>,
#   <matplotlib.axis.XTick at 0x22f76585b50>,
#   <matplotlib.axis.XTick at 0x22f77c7d880>,
#   <matplotlib.axis.XTick at 0x22f77f100d0>,
#   <matplotlib.axis.XTick at 0x22f77f10760>,
#   <matplotlib.axis.XTick at 0x22f77f10eb0>,
#   <matplotlib.axis.XTick at 0x22f77f10400>,
#   <matplotlib.axis.XTick at 0x22f76585e20>,
#   <matplotlib.axis.XTick at 0x22f77f16400>,
#   <matplotlib.axis.XTick at 0x22f77f16b50>,
#   <matplotlib.axis.XTick at 0x22f77f1d2e0>,
#   <matplotlib.axis.XTick at 0x22f77f1da30>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Môn GDCD
from matplotlib import pyplot as plt
# %matplotlib inline
 
# Trung bình và trung vị 
gdcd.mean(), np.median(gdcd)

# Xem có bao nhiêu đầu điểm
unique = np.unique(gdcd)
print(unique)

# Đếm xem mỗi đầu điểm có bao nhiêu người
a = list(gdcd)
freq = [a.count(b) for b in unique]
print(freq)

# Đồ thị
plt.bar(unique, freq, width=0.3)
plt.xticks(unique, rotation=90)
# Out:
# [0.   5.33 5.58 5.75 6.   6.08 6.17 6.25 6.42 6.5  6.58 6.67 6.75 6.83
#  6.92 7.   7.08 7.17 7.25 7.33 7.42 7.5  7.58 7.67 7.75 7.83 7.92 8.
#  8.08 8.17 8.25 8.33 8.42 8.5  8.58 8.67 8.75 8.83 8.92 9.   9.08 9.17
#  9.25 9.33 9.42 9.5  9.58 9.67 9.75 9.83]
# [5798, 1, 2, 1, 1, 2, 2, 3, 3, 6, 4, 6, 4, 4, 7, 8, 10, 8, 10, 8, 13, 9, 23, 18, 13, 10, 10, 12, 20, 20, 9, 20, 13, 15, 21, 16, 15, 15, 10, 8, 15, 14, 7, 3, 7, 4, 4, 3, 1, 1]
# ([<matplotlib.axis.XTick at 0x22f77f87400>,
#   <matplotlib.axis.XTick at 0x22f77f873d0>,
#   <matplotlib.axis.XTick at 0x22f76585fa0>,
#   <matplotlib.axis.XTick at 0x22f7800f490>,
#   <matplotlib.axis.XTick at 0x22f7800fbe0>,
#   <matplotlib.axis.XTick at 0x22f78016370>,
#   <matplotlib.axis.XTick at 0x22f78016ac0>,
#   <matplotlib.axis.XTick at 0x22f78016cd0>,
#   <matplotlib.axis.XTick at 0x22f7800fb80>,
#   <matplotlib.axis.XTick at 0x22f7801c490>,
#   <matplotlib.axis.XTick at 0x22f7801cbe0>,
#   <matplotlib.axis.XTick at 0x22f78023370>,
#   <matplotlib.axis.XTick at 0x22f78023ac0>,
#   <matplotlib.axis.XTick at 0x22f7802a250>,
#   <matplotlib.axis.XTick at 0x22f78023b20>,
#   <matplotlib.axis.XTick at 0x22f7801c7c0>,
#   <matplotlib.axis.XTick at 0x22f7802a1f0>,
#   <matplotlib.axis.XTick at 0x22f7802aeb0>,
#   <matplotlib.axis.XTick at 0x22f78031640>,
#   <matplotlib.axis.XTick at 0x22f78031d90>,
#   <matplotlib.axis.XTick at 0x22f78036520>,
#   <matplotlib.axis.XTick at 0x22f78031850>,
#   <matplotlib.axis.XTick at 0x22f77f9b6d0>,
#   <matplotlib.axis.XTick at 0x22f780360d0>,
#   <matplotlib.axis.XTick at 0x22f7803a160>,
#   <matplotlib.axis.XTick at 0x22f7803a7f0>,
#   <matplotlib.axis.XTick at 0x22f7803af40>,
#   <matplotlib.axis.XTick at 0x22f780466d0>,
#   <matplotlib.axis.XTick at 0x22f7803a370>,
#   <matplotlib.axis.XTick at 0x22f7802ab50>,
#   <matplotlib.axis.XTick at 0x22f78046ac0>,
#   <matplotlib.axis.XTick at 0x22f7804d250>,
#   <matplotlib.axis.XTick at 0x22f7804d9a0>,
#   <matplotlib.axis.XTick at 0x22f78053130>,
#   <matplotlib.axis.XTick at 0x22f7804dcd0>,
#   <matplotlib.axis.XTick at 0x22f7803ac40>,
#   <matplotlib.axis.XTick at 0x22f78036fa0>,
#   <matplotlib.axis.XTick at 0x22f78053910>,
#   <matplotlib.axis.XTick at 0x22f78053d90>,
#   <matplotlib.axis.XTick at 0x22f7805d520>,
#   <matplotlib.axis.XTick at 0x22f7805dc70>,
#   <matplotlib.axis.XTick at 0x22f7805d850>,
#   <matplotlib.axis.XTick at 0x22f780536a0>,
#   <matplotlib.axis.XTick at 0x22f78063280>,
#   <matplotlib.axis.XTick at 0x22f78063910>,
#   <matplotlib.axis.XTick at 0x22f78069160>,
#   <matplotlib.axis.XTick at 0x22f780697f0>,
#   <matplotlib.axis.XTick at 0x22f78069f40>,
#   <matplotlib.axis.XTick at 0x22f78069850>,
#   <matplotlib.axis.XTick at 0x22f780634f0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
